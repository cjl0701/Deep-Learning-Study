# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint, EarlyStopping

import pandas as pd
import numpy
import tensorflow as tf
import matplotlib.pyplot as plt
import os

# seed 값 설정
seed = 0
numpy.random.seed(seed)
tf.random.set_seed(seed)

# 데이터 입력
df_pre = pd.read_csv('C:/Users/JAELYANG/dataset/wine.csv', header=None)
df=df_pre.sample(frac=0.15)

dataset = df.values;
X = dataset[:,0:12]
Y = dataset[:,12]

# 모델 설정
model = Sequential()
model.add(Dense(30, input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 모델 컴파일
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# 모델 저장 폴더 설정
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)
modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"

# 모델 업데이트 및 저장
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)

# 학습 자동 중단 설정
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=100)

# 모델 실행 및 저장
model.fit(X,Y,validation_split=0.2,epochs=3500, batch_size=500, verbose=0, callbacks=[early_stopping_callback, checkpointer])


# 결과 출력
print("\n Accuracy: %.4f" % (model.evaluate(X,Y)[1]))
# Out:
# Epoch 00001: val_loss improved from inf to 0.48962, saving model to ./model/01-0.4896.hdf5
#
# Epoch 00002: val_loss improved from 0.48962 to 0.46440, saving model to ./model/02-0.4644.hdf5
#
# Epoch 00003: val_loss improved from 0.46440 to 0.43658, saving model to ./model/03-0.4366.hdf5
#
# Epoch 00004: val_loss improved from 0.43658 to 0.42121, saving model to ./model/04-0.4212.hdf5
#
# Epoch 00005: val_loss improved from 0.42121 to 0.41025, saving model to ./model/05-0.4103.hdf5
#
# Epoch 00006: val_loss improved from 0.41025 to 0.39668, saving model to ./model/06-0.3967.hdf5
#
# Epoch 00007: val_loss improved from 0.39668 to 0.38734, saving model to ./model/07-0.3873.hdf5
#
# Epoch 00008: val_loss improved from 0.38734 to 0.38055, saving model to ./model/08-0.3805.hdf5
#
# Epoch 00009: val_loss improved from 0.38055 to 0.37399, saving model to ./model/09-0.3740.hdf5
#
# Epoch 00010: val_loss improved from 0.37399 to 0.36726, saving model to ./model/10-0.3673.hdf5
#
# Epoch 00011: val_loss improved from 0.36726 to 0.36062, saving model to ./model/11-0.3606.hdf5
#
# Epoch 00012: val_loss improved from 0.36062 to 0.35496, saving model to ./model/12-0.3550.hdf5
#
# Epoch 00013: val_loss improved from 0.35496 to 0.35004, saving model to ./model/13-0.3500.hdf5
#
# Epoch 00014: val_loss improved from 0.35004 to 0.34553, saving model to ./model/14-0.3455.hdf5
#
# Epoch 00015: val_loss improved from 0.34553 to 0.34008, saving model to ./model/15-0.3401.hdf5
#
# Epoch 00016: val_loss improved from 0.34008 to 0.33455, saving model to ./model/16-0.3345.hdf5
#
# Epoch 00017: val_loss improved from 0.33455 to 0.32982, saving model to ./model/17-0.3298.hdf5
#
# Epoch 00018: val_loss improved from 0.32982 to 0.32575, saving model to ./model/18-0.3258.hdf5
#
# Epoch 00019: val_loss improved from 0.32575 to 0.32375, saving model to ./model/19-0.3237.hdf5
#
# Epoch 00020: val_loss improved from 0.32375 to 0.32027, saving model to ./model/20-0.3203.hdf5
#
# Epoch 00021: val_loss improved from 0.32027 to 0.31358, saving model to ./model/21-0.3136.hdf5
#
# Epoch 00022: val_loss improved from 0.31358 to 0.30886, saving model to ./model/22-0.3089.hdf5
#
# Epoch 00023: val_loss improved from 0.30886 to 0.30488, saving model to ./model/23-0.3049.hdf5
#
# Epoch 00024: val_loss improved from 0.30488 to 0.30149, saving model to ./model/24-0.3015.hdf5
#
# Epoch 00025: val_loss improved from 0.30149 to 0.29895, saving model to ./model/25-0.2990.hdf5
#
# Epoch 00026: val_loss improved from 0.29895 to 0.29455, saving model to ./model/26-0.2945.hdf5
#
# Epoch 00027: val_loss improved from 0.29455 to 0.28916, saving model to ./model/27-0.2892.hdf5
#
# Epoch 00028: val_loss improved from 0.28916 to 0.28476, saving model to ./model/28-0.2848.hdf5
#
# Epoch 00029: val_loss improved from 0.28476 to 0.28032, saving model to ./model/29-0.2803.hdf5
#
# Epoch 00030: val_loss improved from 0.28032 to 0.27733, saving model to ./model/30-0.2773.hdf5
#
# Epoch 00031: val_loss improved from 0.27733 to 0.27308, saving model to ./model/31-0.2731.hdf5
#
# Epoch 00032: val_loss improved from 0.27308 to 0.26871, saving model to ./model/32-0.2687.hdf5
#
# Epoch 00033: val_loss improved from 0.26871 to 0.26474, saving model to ./model/33-0.2647.hdf5
#
# Epoch 00034: val_loss improved from 0.26474 to 0.26136, saving model to ./model/34-0.2614.hdf5
#
# Epoch 00035: val_loss improved from 0.26136 to 0.25959, saving model to ./model/35-0.2596.hdf5
#
# Epoch 00036: val_loss improved from 0.25959 to 0.25585, saving model to ./model/36-0.2558.hdf5
#
# Epoch 00037: val_loss improved from 0.25585 to 0.25261, saving model to ./model/37-0.2526.hdf5
#
# Epoch 00038: val_loss improved from 0.25261 to 0.25011, saving model to ./model/38-0.2501.hdf5
#
# Epoch 00039: val_loss improved from 0.25011 to 0.24792, saving model to ./model/39-0.2479.hdf5
#
# Epoch 00040: val_loss improved from 0.24792 to 0.24601, saving model to ./model/40-0.2460.hdf5
#
# Epoch 00041: val_loss improved from 0.24601 to 0.24486, saving model to ./model/41-0.2449.hdf5
#
# Epoch 00042: val_loss improved from 0.24486 to 0.24259, saving model to ./model/42-0.2426.hdf5
#
# Epoch 00043: val_loss improved from 0.24259 to 0.24080, saving model to ./model/43-0.2408.hdf5
#
# Epoch 00044: val_loss improved from 0.24080 to 0.23888, saving model to ./model/44-0.2389.hdf5
#
# Epoch 00045: val_loss improved from 0.23888 to 0.23826, saving model to ./model/45-0.2383.hdf5
#
# Epoch 00046: val_loss improved from 0.23826 to 0.23815, saving model to ./model/46-0.2382.hdf5
#
# Epoch 00047: val_loss improved from 0.23815 to 0.23543, saving model to ./model/47-0.2354.hdf5
#
# Epoch 00048: val_loss improved from 0.23543 to 0.23274, saving model to ./model/48-0.2327.hdf5
#
# Epoch 00049: val_loss improved from 0.23274 to 0.23113, saving model to ./model/49-0.2311.hdf5
#
# Epoch 00050: val_loss improved from 0.23113 to 0.23044, saving model to ./model/50-0.2304.hdf5
#
# Epoch 00051: val_loss improved from 0.23044 to 0.22846, saving model to ./model/51-0.2285.hdf5
#
# Epoch 00052: val_loss improved from 0.22846 to 0.22708, saving model to ./model/52-0.2271.hdf5
#
# Epoch 00053: val_loss improved from 0.22708 to 0.22559, saving model to ./model/53-0.2256.hdf5
#
# Epoch 00054: val_loss improved from 0.22559 to 0.22485, saving model to ./model/54-0.2248.hdf5
#
# Epoch 00055: val_loss improved from 0.22485 to 0.22381, saving model to ./model/55-0.2238.hdf5
#
# Epoch 00056: val_loss improved from 0.22381 to 0.22191, saving model to ./model/56-0.2219.hdf5
#
# Epoch 00057: val_loss improved from 0.22191 to 0.22043, saving model to ./model/57-0.2204.hdf5
#
# Epoch 00058: val_loss improved from 0.22043 to 0.21902, saving model to ./model/58-0.2190.hdf5
#
# Epoch 00059: val_loss improved from 0.21902 to 0.21772, saving model to ./model/59-0.2177.hdf5
#
# Epoch 00060: val_loss improved from 0.21772 to 0.21768, saving model to ./model/60-0.2177.hdf5
#
# Epoch 00061: val_loss did not improve from 0.21768
#
# Epoch 00062: val_loss improved from 0.21768 to 0.21403, saving model to ./model/62-0.2140.hdf5
#
# Epoch 00063: val_loss improved from 0.21403 to 0.21151, saving model to ./model/63-0.2115.hdf5
#
# Epoch 00064: val_loss improved from 0.21151 to 0.21008, saving model to ./model/64-0.2101.hdf5
#
# Epoch 00065: val_loss did not improve from 0.21008
#
# Epoch 00066: val_loss improved from 0.21008 to 0.20895, saving model to ./model/66-0.2090.hdf5
#
# Epoch 00067: val_loss improved from 0.20895 to 0.20608, saving model to ./model/67-0.2061.hdf5
#
# Epoch 00068: val_loss improved from 0.20608 to 0.20516, saving model to ./model/68-0.2052.hdf5
#
# Epoch 00069: val_loss improved from 0.20516 to 0.20368, saving model to ./model/69-0.2037.hdf5
#
# Epoch 00070: val_loss did not improve from 0.20368
#
# Epoch 00071: val_loss did not improve from 0.20368
#
# Epoch 00072: val_loss improved from 0.20368 to 0.20186, saving model to ./model/72-0.2019.hdf5
#
# Epoch 00073: val_loss improved from 0.20186 to 0.19940, saving model to ./model/73-0.1994.hdf5
#
# Epoch 00074: val_loss improved from 0.19940 to 0.19827, saving model to ./model/74-0.1983.hdf5
#
# Epoch 00075: val_loss did not improve from 0.19827
#
# Epoch 00076: val_loss did not improve from 0.19827
#
# Epoch 00077: val_loss improved from 0.19827 to 0.19715, saving model to ./model/77-0.1972.hdf5
#
# Epoch 00078: val_loss improved from 0.19715 to 0.19544, saving model to ./model/78-0.1954.hdf5
#
# Epoch 00079: val_loss improved from 0.19544 to 0.19305, saving model to ./model/79-0.1930.hdf5
#
# Epoch 00080: val_loss improved from 0.19305 to 0.19174, saving model to ./model/80-0.1917.hdf5
#
# Epoch 00081: val_loss did not improve from 0.19174
#
# Epoch 00082: val_loss did not improve from 0.19174
#
# Epoch 00083: val_loss improved from 0.19174 to 0.19116, saving model to ./model/83-0.1912.hdf5
#
# Epoch 00084: val_loss improved from 0.19116 to 0.18834, saving model to ./model/84-0.1883.hdf5
#
# Epoch 00085: val_loss improved from 0.18834 to 0.18759, saving model to ./model/85-0.1876.hdf5
#
# Epoch 00086: val_loss improved from 0.18759 to 0.18739, saving model to ./model/86-0.1874.hdf5
#
# Epoch 00087: val_loss did not improve from 0.18739
#
# Epoch 00088: val_loss did not improve from 0.18739
#
# Epoch 00089: val_loss improved from 0.18739 to 0.18636, saving model to ./model/89-0.1864.hdf5
#
# Epoch 00090: val_loss improved from 0.18636 to 0.18382, saving model to ./model/90-0.1838.hdf5
#
# Epoch 00091: val_loss improved from 0.18382 to 0.18252, saving model to ./model/91-0.1825.hdf5
#
# Epoch 00092: val_loss did not improve from 0.18252
#
# Epoch 00093: val_loss did not improve from 0.18252
# Epoch 00094: val_loss did not improve from 0.18252
#
# Epoch 00095: val_loss improved from 0.18252 to 0.18152, saving model to ./model/95-0.1815.hdf5
#
# Epoch 00096: val_loss improved from 0.18152 to 0.18065, saving model to ./model/96-0.1806.hdf5
#
# Epoch 00097: val_loss improved from 0.18065 to 0.18018, saving model to ./model/97-0.1802.hdf5
#
# Epoch 00098: val_loss improved from 0.18018 to 0.17917, saving model to ./model/98-0.1792.hdf5
#
# Epoch 00099: val_loss improved from 0.17917 to 0.17893, saving model to ./model/99-0.1789.hdf5
#
# Epoch 00100: val_loss improved from 0.17893 to 0.17737, saving model to ./model/100-0.1774.hdf5
#
# Epoch 00101: val_loss improved from 0.17737 to 0.17598, saving model to ./model/101-0.1760.hdf5
#
# Epoch 00102: val_loss improved from 0.17598 to 0.17411, saving model to ./model/102-0.1741.hdf5
#
# Epoch 00103: val_loss improved from 0.17411 to 0.17341, saving model to ./model/103-0.1734.hdf5
#
# Epoch 00104: val_loss did not improve from 0.17341
#
# Epoch 00105: val_loss did not improve from 0.17341
#
# Epoch 00106: val_loss did not improve from 0.17341
#
# Epoch 00107: val_loss improved from 0.17341 to 0.16987, saving model to ./model/107-0.1699.hdf5
#
# Epoch 00108: val_loss improved from 0.16987 to 0.16909, saving model to ./model/108-0.1691.hdf5
#
# Epoch 00109: val_loss did not improve from 0.16909
#
# Epoch 00110: val_loss did not improve from 0.16909
#
# Epoch 00111: val_loss did not improve from 0.16909
#
# Epoch 00112: val_loss improved from 0.16909 to 0.16653, saving model to ./model/112-0.1665.hdf5
#
# Epoch 00113: val_loss improved from 0.16653 to 0.16599, saving model to ./model/113-0.1660.hdf5
#
# Epoch 00114: val_loss did not improve from 0.16599
#
# Epoch 00115: val_loss did not improve from 0.16599
#
# Epoch 00116: val_loss did not improve from 0.16599
#
# Epoch 00117: val_loss improved from 0.16599 to 0.16463, saving model to ./model/117-0.1646.hdf5
#
# Epoch 00118: val_loss improved from 0.16463 to 0.16439, saving model to ./model/118-0.1644.hdf5
#
# Epoch 00119: val_loss did not improve from 0.16439
#
# Epoch 00120: val_loss did not improve from 0.16439
#
# Epoch 00121: val_loss improved from 0.16439 to 0.16368, saving model to ./model/121-0.1637.hdf5
#
# Epoch 00122: val_loss improved from 0.16368 to 0.16030, saving model to ./model/122-0.1603.hdf5
#
# Epoch 00123: val_loss did not improve from 0.16030
#
# Epoch 00124: val_loss did not improve from 0.16030
#
# Epoch 00125: val_loss did not improve from 0.16030
#
# Epoch 00126: val_loss did not improve from 0.16030
#
# Epoch 00127: val_loss improved from 0.16030 to 0.15789, saving model to ./model/127-0.1579.hdf5
#
# Epoch 00128: val_loss did not improve from 0.15789
#
# Epoch 00129: val_loss did not improve from 0.15789
#
# Epoch 00130: val_loss did not improve from 0.15789
#
# Epoch 00131: val_loss did not improve from 0.15789
#
# Epoch 00132: val_loss improved from 0.15789 to 0.15581, saving model to ./model/132-0.1558.hdf5
#
# Epoch 00133: val_loss improved from 0.15581 to 0.15512, saving model to ./model/133-0.1551.hdf5
#
# Epoch 00134: val_loss did not improve from 0.15512
#
# Epoch 00135: val_loss did not improve from 0.15512
#
# Epoch 00136: val_loss improved from 0.15512 to 0.15420, saving model to ./model/136-0.1542.hdf5
#
# Epoch 00137: val_loss improved from 0.15420 to 0.15328, saving model to ./model/137-0.1533.hdf5
#
# Epoch 00138: val_loss did not improve from 0.15328
#
# Epoch 00139: val_loss did not improve from 0.15328
#
# Epoch 00140: val_loss improved from 0.15328 to 0.15215, saving model to ./model/140-0.1522.hdf5
#
# Epoch 00141: val_loss improved from 0.15215 to 0.15107, saving model to ./model/141-0.1511.hdf5
#
# Epoch 00142: val_loss did not improve from 0.15107
#
# Epoch 00143: val_loss did not improve from 0.15107
#
# Epoch 00144: val_loss did not improve from 0.15107
#
# Epoch 00145: val_loss improved from 0.15107 to 0.14897, saving model to ./model/145-0.1490.hdf5
#
# Epoch 00146: val_loss improved from 0.14897 to 0.14864, saving model to ./model/146-0.1486.hdf5
#
# Epoch 00147: val_loss did not improve from 0.14864
#
# Epoch 00148: val_loss did not improve from 0.14864
#
# Epoch 00149: val_loss did not improve from 0.14864
#
# Epoch 00150: val_loss did not improve from 0.14864
#
# Epoch 00151: val_loss did not improve from 0.14864
#
# Epoch 00152: val_loss did not improve from 0.14864
#
# Epoch 00153: val_loss did not improve from 0.14864
#
# Epoch 00154: val_loss improved from 0.14864 to 0.14577, saving model to ./model/154-0.1458.hdf5
#
# Epoch 00155: val_loss improved from 0.14577 to 0.14401, saving model to ./model/155-0.1440.hdf5
#
# Epoch 00156: val_loss did not improve from 0.14401
#
# Epoch 00157: val_loss did not improve from 0.14401
#
# Epoch 00158: val_loss did not improve from 0.14401
#
# Epoch 00159: val_loss did not improve from 0.14401
#
# Epoch 00160: val_loss improved from 0.14401 to 0.14319, saving model to ./model/160-0.1432.hdf5
#
# Epoch 00161: val_loss did not improve from 0.14319
#
# Epoch 00162: val_loss did not improve from 0.14319
#
# Epoch 00163: val_loss improved from 0.14319 to 0.14242, saving model to ./model/163-0.1424.hdf5
#
# Epoch 00164: val_loss improved from 0.14242 to 0.14051, saving model to ./model/164-0.1405.hdf5
#
# Epoch 00165: val_loss did not improve from 0.14051
#
# Epoch 00166: val_loss did not improve from 0.14051
#
# Epoch 00167: val_loss did not improve from 0.14051
#
# Epoch 00168: val_loss improved from 0.14051 to 0.13921, saving model to ./model/168-0.1392.hdf5
#
# Epoch 00169: val_loss improved from 0.13921 to 0.13828, saving model to ./model/169-0.1383.hdf5
#
# Epoch 00170: val_loss did not improve from 0.13828
#
# Epoch 00171: val_loss did not improve from 0.13828
#
# Epoch 00172: val_loss did not improve from 0.13828
#
# Epoch 00173: val_loss did not improve from 0.13828
#
# Epoch 00174: val_loss did not improve from 0.13828
#
# Epoch 00175: val_loss did not improve from 0.13828
#
# Epoch 00176: val_loss improved from 0.13828 to 0.13524, saving model to ./model/176-0.1352.hdf5
#
# Epoch 00177: val_loss did not improve from 0.13524
#
# Epoch 00178: val_loss did not improve from 0.13524
#
# Epoch 00179: val_loss did not improve from 0.13524
#
# Epoch 00180: val_loss did not improve from 0.13524
#
# Epoch 00181: val_loss improved from 0.13524 to 0.13331, saving model to ./model/181-0.1333.hdf5
#
# Epoch 00182: val_loss did not improve from 0.13331
#
# Epoch 00183: val_loss did not improve from 0.13331
#
# Epoch 00184: val_loss did not improve from 0.13331
#
# Epoch 00185: val_loss did not improve from 0.13331
#
# Epoch 00186: val_loss improved from 0.13331 to 0.13256, saving model to ./model/186-0.1326.hdf5
#
# Epoch 00187: val_loss did not improve from 0.13256
#
# Epoch 00188: val_loss did not improve from 0.13256
#
# Epoch 00189: val_loss did not improve from 0.13256
#
# Epoch 00190: val_loss improved from 0.13256 to 0.13036, saving model to ./model/190-0.1304.hdf5
#
# Epoch 00191: val_loss did not improve from 0.13036
#
# Epoch 00192: val_loss did not improve from 0.13036
#
# Epoch 00193: val_loss did not improve from 0.13036
#
# Epoch 00194: val_loss improved from 0.13036 to 0.13005, saving model to ./model/194-0.1301.hdf5
#
# Epoch 00195: val_loss did not improve from 0.13005
#
# Epoch 00196: val_loss did not improve from 0.13005
#
# Epoch 00197: val_loss improved from 0.13005 to 0.12976, saving model to ./model/197-0.1298.hdf5
#
# Epoch 00198: val_loss improved from 0.12976 to 0.12754, saving model to ./model/198-0.1275.hdf5
#
# Epoch 00199: val_loss did not improve from 0.12754
#
# Epoch 00200: val_loss did not improve from 0.12754
#
# Epoch 00201: val_loss did not improve from 0.12754
#
# Epoch 00202: val_loss improved from 0.12754 to 0.12660, saving model to ./model/202-0.1266.hdf5
#
# Epoch 00203: val_loss did not improve from 0.12660
#
# Epoch 00204: val_loss did not improve from 0.12660
#
# Epoch 00205: val_loss did not improve from 0.12660
#
# Epoch 00206: val_loss improved from 0.12660 to 0.12589, saving model to ./model/206-0.1259.hdf5
#
# Epoch 00207: val_loss did not improve from 0.12589
#
# Epoch 00208: val_loss did not improve from 0.12589
#
# Epoch 00209: val_loss did not improve from 0.12589
#
# Epoch 00210: val_loss did not improve from 0.12589
#
# Epoch 00211: val_loss improved from 0.12589 to 0.12497, saving model to ./model/211-0.1250.hdf5
#
# Epoch 00212: val_loss did not improve from 0.12497
#
# Epoch 00213: val_loss did not improve from 0.12497
#
# Epoch 00214: val_loss did not improve from 0.12497
#
# Epoch 00215: val_loss improved from 0.12497 to 0.12360, saving model to ./model/215-0.1236.hdf5
#
# Epoch 00216: val_loss did not improve from 0.12360
#
# Epoch 00217: val_loss did not improve from 0.12360
#
# Epoch 00218: val_loss did not improve from 0.12360
#
# Epoch 00219: val_loss did not improve from 0.12360
#
# Epoch 00220: val_loss did not improve from 0.12360
#
# Epoch 00221: val_loss did not improve from 0.12360
#
# Epoch 00222: val_loss did not improve from 0.12360
#
# Epoch 00223: val_loss did not improve from 0.12360
#
# Epoch 00224: val_loss did not improve from 0.12360
#
# Epoch 00225: val_loss did not improve from 0.12360
#
# Epoch 00226: val_loss did not improve from 0.12360
#
# Epoch 00227: val_loss improved from 0.12360 to 0.12218, saving model to ./model/227-0.1222.hdf5
#
# Epoch 00228: val_loss did not improve from 0.12218
# Epoch 00229: val_loss did not improve from 0.12218
#
# Epoch 00230: val_loss improved from 0.12218 to 0.12079, saving model to ./model/230-0.1208.hdf5
#
# Epoch 00231: val_loss improved from 0.12079 to 0.11949, saving model to ./model/231-0.1195.hdf5
#
# Epoch 00232: val_loss did not improve from 0.11949
#
# Epoch 00233: val_loss did not improve from 0.11949
#
# Epoch 00234: val_loss improved from 0.11949 to 0.11854, saving model to ./model/234-0.1185.hdf5
#
# Epoch 00235: val_loss did not improve from 0.11854
#
# Epoch 00236: val_loss did not improve from 0.11854
#
# Epoch 00237: val_loss did not improve from 0.11854
#
# Epoch 00238: val_loss improved from 0.11854 to 0.11793, saving model to ./model/238-0.1179.hdf5
#
# Epoch 00239: val_loss did not improve from 0.11793
#
# Epoch 00240: val_loss did not improve from 0.11793
#
# Epoch 00241: val_loss did not improve from 0.11793
#
# Epoch 00242: val_loss improved from 0.11793 to 0.11582, saving model to ./model/242-0.1158.hdf5
#
# Epoch 00243: val_loss did not improve from 0.11582
#
# Epoch 00244: val_loss did not improve from 0.11582
#
# Epoch 00245: val_loss did not improve from 0.11582
#
# Epoch 00246: val_loss did not improve from 0.11582
#
# Epoch 00247: val_loss did not improve from 0.11582
#
# Epoch 00248: val_loss did not improve from 0.11582
#
# Epoch 00249: val_loss improved from 0.11582 to 0.11564, saving model to ./model/249-0.1156.hdf5
#
# Epoch 00250: val_loss improved from 0.11564 to 0.11352, saving model to ./model/250-0.1135.hdf5
#
# Epoch 00251: val_loss did not improve from 0.11352
#
# Epoch 00252: val_loss did not improve from 0.11352
#
# Epoch 00253: val_loss did not improve from 0.11352
#
# Epoch 00254: val_loss improved from 0.11352 to 0.11351, saving model to ./model/254-0.1135.hdf5
#
# Epoch 00255: val_loss did not improve from 0.11351
#
# Epoch 00256: val_loss did not improve from 0.11351
#
# Epoch 00257: val_loss did not improve from 0.11351
#
# Epoch 00258: val_loss improved from 0.11351 to 0.11292, saving model to ./model/258-0.1129.hdf5
#
# Epoch 00259: val_loss did not improve from 0.11292
#
# Epoch 00260: val_loss did not improve from 0.11292
#
# Epoch 00261: val_loss improved from 0.11292 to 0.11255, saving model to ./model/261-0.1126.hdf5
#
# Epoch 00262: val_loss improved from 0.11255 to 0.11149, saving model to ./model/262-0.1115.hdf5
#
# Epoch 00263: val_loss did not improve from 0.11149
#
# Epoch 00264: val_loss did not improve from 0.11149
#
# Epoch 00265: val_loss did not improve from 0.11149
#
# Epoch 00266: val_loss improved from 0.11149 to 0.10871, saving model to ./model/266-0.1087.hdf5
#
# Epoch 00267: val_loss did not improve from 0.10871
#
# Epoch 00268: val_loss did not improve from 0.10871
#
# Epoch 00269: val_loss did not improve from 0.10871
#
# Epoch 00270: val_loss did not improve from 0.10871
#
# Epoch 00271: val_loss did not improve from 0.10871
#
# Epoch 00272: val_loss did not improve from 0.10871
#
# Epoch 00273: val_loss did not improve from 0.10871
#
# Epoch 00274: val_loss did not improve from 0.10871
#
# Epoch 00275: val_loss did not improve from 0.10871
#
# Epoch 00276: val_loss did not improve from 0.10871
#
# Epoch 00277: val_loss did not improve from 0.10871
#
# Epoch 00278: val_loss did not improve from 0.10871
#
# Epoch 00279: val_loss improved from 0.10871 to 0.10805, saving model to ./model/279-0.1080.hdf5
#
# Epoch 00280: val_loss did not improve from 0.10805
#
# Epoch 00281: val_loss did not improve from 0.10805
#
# Epoch 00282: val_loss did not improve from 0.10805
#
# Epoch 00283: val_loss did not improve from 0.10805
#
# Epoch 00284: val_loss did not improve from 0.10805
#
# Epoch 00285: val_loss did not improve from 0.10805
#
# Epoch 00286: val_loss did not improve from 0.10805
#
# Epoch 00287: val_loss improved from 0.10805 to 0.10625, saving model to ./model/287-0.1062.hdf5
#
# Epoch 00288: val_loss improved from 0.10625 to 0.10625, saving model to ./model/288-0.1062.hdf5
#
# Epoch 00289: val_loss did not improve from 0.10625
#
# Epoch 00290: val_loss did not improve from 0.10625
#
# Epoch 00291: val_loss did not improve from 0.10625
#
# Epoch 00292: val_loss improved from 0.10625 to 0.10418, saving model to ./model/292-0.1042.hdf5
#
# Epoch 00293: val_loss did not improve from 0.10418
#
# Epoch 00294: val_loss did not improve from 0.10418
#
# Epoch 00295: val_loss did not improve from 0.10418
#
# Epoch 00296: val_loss did not improve from 0.10418
#
# Epoch 00297: val_loss did not improve from 0.10418
#
# Epoch 00298: val_loss did not improve from 0.10418
#
# Epoch 00299: val_loss improved from 0.10418 to 0.10047, saving model to ./model/299-0.1005.hdf5
#
# Epoch 00300: val_loss did not improve from 0.10047
#
# Epoch 00301: val_loss did not improve from 0.10047
#
# Epoch 00302: val_loss did not improve from 0.10047
#
# Epoch 00303: val_loss improved from 0.10047 to 0.10029, saving model to ./model/303-0.1003.hdf5
#
# Epoch 00304: val_loss did not improve from 0.10029
#
# Epoch 00305: val_loss did not improve from 0.10029
#
# Epoch 00306: val_loss improved from 0.10029 to 0.09913, saving model to ./model/306-0.0991.hdf5
#
# Epoch 00307: val_loss did not improve from 0.09913
#
# Epoch 00308: val_loss did not improve from 0.09913
#
# Epoch 00309: val_loss did not improve from 0.09913
#
# Epoch 00310: val_loss improved from 0.09913 to 0.09871, saving model to ./model/310-0.0987.hdf5
#
# Epoch 00311: val_loss did not improve from 0.09871
#
# Epoch 00312: val_loss did not improve from 0.09871
#
# Epoch 00313: val_loss did not improve from 0.09871
#
# Epoch 00314: val_loss did not improve from 0.09871
#
# Epoch 00315: val_loss did not improve from 0.09871
#
# Epoch 00316: val_loss did not improve from 0.09871
#
# Epoch 00317: val_loss did not improve from 0.09871
#
# Epoch 00318: val_loss did not improve from 0.09871
#
# Epoch 00319: val_loss did not improve from 0.09871
#
# Epoch 00320: val_loss improved from 0.09871 to 0.09758, saving model to ./model/320-0.0976.hdf5
#
# Epoch 00321: val_loss did not improve from 0.09758
#
# Epoch 00322: val_loss did not improve from 0.09758
#
# Epoch 00323: val_loss improved from 0.09758 to 0.09585, saving model to ./model/323-0.0959.hdf5
#
# Epoch 00324: val_loss did not improve from 0.09585
#
# Epoch 00325: val_loss did not improve from 0.09585
#
# Epoch 00326: val_loss did not improve from 0.09585
#
# Epoch 00327: val_loss did not improve from 0.09585
#
# Epoch 00328: val_loss did not improve from 0.09585
#
# Epoch 00329: val_loss did not improve from 0.09585
#
# Epoch 00330: val_loss improved from 0.09585 to 0.09386, saving model to ./model/330-0.0939.hdf5
#
# Epoch 00331: val_loss did not improve from 0.09386
#
# Epoch 00332: val_loss did not improve from 0.09386
#
# Epoch 00333: val_loss did not improve from 0.09386
#
# Epoch 00334: val_loss improved from 0.09386 to 0.09347, saving model to ./model/334-0.0935.hdf5
#
# Epoch 00335: val_loss did not improve from 0.09347
#
# Epoch 00336: val_loss did not improve from 0.09347
#
# Epoch 00337: val_loss improved from 0.09347 to 0.09193, saving model to ./model/337-0.0919.hdf5
#
# Epoch 00338: val_loss did not improve from 0.09193
#
# Epoch 00339: val_loss did not improve from 0.09193
#
# Epoch 00340: val_loss did not improve from 0.09193
#
# Epoch 00341: val_loss did not improve from 0.09193
#
# Epoch 00342: val_loss did not improve from 0.09193
#
# Epoch 00343: val_loss did not improve from 0.09193
#
# Epoch 00344: val_loss did not improve from 0.09193
#
# Epoch 00345: val_loss did not improve from 0.09193
#
# Epoch 00346: val_loss did not improve from 0.09193
#
# Epoch 00347: val_loss did not improve from 0.09193
#
# Epoch 00348: val_loss did not improve from 0.09193
#
# Epoch 00349: val_loss did not improve from 0.09193
#
# Epoch 00350: val_loss did not improve from 0.09193
#
# Epoch 00351: val_loss did not improve from 0.09193
#
# Epoch 00352: val_loss did not improve from 0.09193
#
# Epoch 00353: val_loss did not improve from 0.09193
#
# Epoch 00354: val_loss did not improve from 0.09193
#
# Epoch 00355: val_loss did not improve from 0.09193
#
# Epoch 00356: val_loss improved from 0.09193 to 0.09088, saving model to ./model/356-0.0909.hdf5
#
# Epoch 00357: val_loss did not improve from 0.09088
#
# Epoch 00358: val_loss did not improve from 0.09088
#
# Epoch 00359: val_loss did not improve from 0.09088
#
# Epoch 00360: val_loss did not improve from 0.09088
#
# Epoch 00361: val_loss did not improve from 0.09088
#
# Epoch 00362: val_loss improved from 0.09088 to 0.08932, saving model to ./model/362-0.0893.hdf5
#
# Epoch 00363: val_loss did not improve from 0.08932
#
# Epoch 00364: val_loss did not improve from 0.08932
#
# Epoch 00365: val_loss did not improve from 0.08932
#
# Epoch 00366: val_loss did not improve from 0.08932
#
# Epoch 00367: val_loss did not improve from 0.08932
#
# Epoch 00368: val_loss did not improve from 0.08932
#
# Epoch 00369: val_loss did not improve from 0.08932
#
# Epoch 00370: val_loss improved from 0.08932 to 0.08678, saving model to ./model/370-0.0868.hdf5
#
# Epoch 00371: val_loss did not improve from 0.08678
#
# Epoch 00372: val_loss did not improve from 0.08678
#
# Epoch 00373: val_loss did not improve from 0.08678
#
# Epoch 00374: val_loss improved from 0.08678 to 0.08530, saving model to ./model/374-0.0853.hdf5
#
# Epoch 00375: val_loss did not improve from 0.08530
#
# Epoch 00376: val_loss did not improve from 0.08530
#
# Epoch 00377: val_loss did not improve from 0.08530
#
# Epoch 00378: val_loss improved from 0.08530 to 0.08492, saving model to ./model/378-0.0849.hdf5
#
# Epoch 00379: val_loss did not improve from 0.08492
#
# Epoch 00380: val_loss did not improve from 0.08492
#
# Epoch 00381: val_loss did not improve from 0.08492
# Epoch 00382: val_loss did not improve from 0.08492
#
# Epoch 00383: val_loss did not improve from 0.08492
#
# Epoch 00384: val_loss did not improve from 0.08492
#
# Epoch 00385: val_loss did not improve from 0.08492
#
# Epoch 00386: val_loss improved from 0.08492 to 0.08384, saving model to ./model/386-0.0838.hdf5
#
# Epoch 00387: val_loss did not improve from 0.08384
#
# Epoch 00388: val_loss did not improve from 0.08384
#
# Epoch 00389: val_loss did not improve from 0.08384
#
# Epoch 00390: val_loss improved from 0.08384 to 0.08316, saving model to ./model/390-0.0832.hdf5
#
# Epoch 00391: val_loss did not improve from 0.08316
#
# Epoch 00392: val_loss did not improve from 0.08316
#
# Epoch 00393: val_loss did not improve from 0.08316
#
# Epoch 00394: val_loss did not improve from 0.08316
#
# Epoch 00395: val_loss did not improve from 0.08316
#
# Epoch 00396: val_loss did not improve from 0.08316
#
# Epoch 00397: val_loss improved from 0.08316 to 0.08062, saving model to ./model/397-0.0806.hdf5
#
# Epoch 00398: val_loss did not improve from 0.08062
#
# Epoch 00399: val_loss did not improve from 0.08062
#
# Epoch 00400: val_loss did not improve from 0.08062
#
# Epoch 00401: val_loss did not improve from 0.08062
#
# Epoch 00402: val_loss did not improve from 0.08062
#
# Epoch 00403: val_loss did not improve from 0.08062
#
# Epoch 00404: val_loss did not improve from 0.08062
#
# Epoch 00405: val_loss did not improve from 0.08062
#
# Epoch 00406: val_loss did not improve from 0.08062
#
# Epoch 00407: val_loss improved from 0.08062 to 0.07956, saving model to ./model/407-0.0796.hdf5
#
# Epoch 00408: val_loss did not improve from 0.07956
#
# Epoch 00409: val_loss did not improve from 0.07956
#
# Epoch 00410: val_loss did not improve from 0.07956
#
# Epoch 00411: val_loss did not improve from 0.07956
#
# Epoch 00412: val_loss did not improve from 0.07956
#
# Epoch 00413: val_loss did not improve from 0.07956
#
# Epoch 00414: val_loss did not improve from 0.07956
#
# Epoch 00415: val_loss did not improve from 0.07956
#
# Epoch 00416: val_loss did not improve from 0.07956
#
# Epoch 00417: val_loss did not improve from 0.07956
#
# Epoch 00418: val_loss improved from 0.07956 to 0.07920, saving model to ./model/418-0.0792.hdf5
#
# Epoch 00419: val_loss did not improve from 0.07920
#
# Epoch 00420: val_loss did not improve from 0.07920
#
# Epoch 00421: val_loss improved from 0.07920 to 0.07672, saving model to ./model/421-0.0767.hdf5
#
# Epoch 00422: val_loss did not improve from 0.07672
#
# Epoch 00423: val_loss did not improve from 0.07672
#
# Epoch 00424: val_loss did not improve from 0.07672
#
# Epoch 00425: val_loss improved from 0.07672 to 0.07577, saving model to ./model/425-0.0758.hdf5
#
# Epoch 00426: val_loss did not improve from 0.07577
#
# Epoch 00427: val_loss did not improve from 0.07577
#
# Epoch 00428: val_loss did not improve from 0.07577
#
# Epoch 00429: val_loss improved from 0.07577 to 0.07564, saving model to ./model/429-0.0756.hdf5
#
# Epoch 00430: val_loss did not improve from 0.07564
#
# Epoch 00431: val_loss did not improve from 0.07564
#
# Epoch 00432: val_loss improved from 0.07564 to 0.07516, saving model to ./model/432-0.0752.hdf5
#
# Epoch 00433: val_loss did not improve from 0.07516
#
# Epoch 00434: val_loss did not improve from 0.07516
#
# Epoch 00435: val_loss did not improve from 0.07516
#
# Epoch 00436: val_loss did not improve from 0.07516
#
# Epoch 00437: val_loss did not improve from 0.07516
#
# Epoch 00438: val_loss did not improve from 0.07516
#
# Epoch 00439: val_loss improved from 0.07516 to 0.07457, saving model to ./model/439-0.0746.hdf5
#
# Epoch 00440: val_loss did not improve from 0.07457
#
# Epoch 00441: val_loss did not improve from 0.07457
#
# Epoch 00442: val_loss did not improve from 0.07457
#
# Epoch 00443: val_loss did not improve from 0.07457
#
# Epoch 00444: val_loss did not improve from 0.07457
#
# Epoch 00445: val_loss did not improve from 0.07457
#
# Epoch 00446: val_loss did not improve from 0.07457
#
# Epoch 00447: val_loss did not improve from 0.07457
#
# Epoch 00448: val_loss improved from 0.07457 to 0.07280, saving model to ./model/448-0.0728.hdf5
#
# Epoch 00449: val_loss did not improve from 0.07280
#
# Epoch 00450: val_loss did not improve from 0.07280
#
# Epoch 00451: val_loss did not improve from 0.07280
#
# Epoch 00452: val_loss improved from 0.07280 to 0.07273, saving model to ./model/452-0.0727.hdf5
#
# Epoch 00453: val_loss did not improve from 0.07273
#
# Epoch 00454: val_loss did not improve from 0.07273
#
# Epoch 00455: val_loss did not improve from 0.07273
#
# Epoch 00456: val_loss did not improve from 0.07273
#
# Epoch 00457: val_loss did not improve from 0.07273
#
# Epoch 00458: val_loss did not improve from 0.07273
#
# Epoch 00459: val_loss improved from 0.07273 to 0.07164, saving model to ./model/459-0.0716.hdf5
#
# Epoch 00460: val_loss did not improve from 0.07164
#
# Epoch 00461: val_loss did not improve from 0.07164
#
# Epoch 00462: val_loss did not improve from 0.07164
#
# Epoch 00463: val_loss did not improve from 0.07164
#
# Epoch 00464: val_loss did not improve from 0.07164
#
# Epoch 00465: val_loss did not improve from 0.07164
#
# Epoch 00466: val_loss did not improve from 0.07164
#
# Epoch 00467: val_loss did not improve from 0.07164
#
# Epoch 00468: val_loss did not improve from 0.07164
#
# Epoch 00469: val_loss did not improve from 0.07164
#
# Epoch 00470: val_loss did not improve from 0.07164
#
# Epoch 00471: val_loss did not improve from 0.07164
#
# Epoch 00472: val_loss did not improve from 0.07164
#
# Epoch 00473: val_loss did not improve from 0.07164
#
# Epoch 00474: val_loss did not improve from 0.07164
#
# Epoch 00475: val_loss improved from 0.07164 to 0.07033, saving model to ./model/475-0.0703.hdf5
#
# Epoch 00476: val_loss did not improve from 0.07033
#
# Epoch 00477: val_loss did not improve from 0.07033
#
# Epoch 00478: val_loss did not improve from 0.07033
#
# Epoch 00479: val_loss did not improve from 0.07033
#
# Epoch 00480: val_loss did not improve from 0.07033
#
# Epoch 00481: val_loss did not improve from 0.07033
#
# Epoch 00482: val_loss did not improve from 0.07033
#
# Epoch 00483: val_loss did not improve from 0.07033
#
# Epoch 00484: val_loss did not improve from 0.07033
#
# Epoch 00485: val_loss did not improve from 0.07033
#
# Epoch 00486: val_loss did not improve from 0.07033
#
# Epoch 00487: val_loss did not improve from 0.07033
#
# Epoch 00488: val_loss improved from 0.07033 to 0.07028, saving model to ./model/488-0.0703.hdf5
#
# Epoch 00489: val_loss did not improve from 0.07028
#
# Epoch 00490: val_loss did not improve from 0.07028
#
# Epoch 00491: val_loss did not improve from 0.07028
#
# Epoch 00492: val_loss improved from 0.07028 to 0.07005, saving model to ./model/492-0.0701.hdf5
#
# Epoch 00493: val_loss did not improve from 0.07005
#
# Epoch 00494: val_loss did not improve from 0.07005
#
# Epoch 00495: val_loss improved from 0.07005 to 0.06959, saving model to ./model/495-0.0696.hdf5
#
# Epoch 00496: val_loss did not improve from 0.06959
#
# Epoch 00497: val_loss did not improve from 0.06959
#
# Epoch 00498: val_loss improved from 0.06959 to 0.06773, saving model to ./model/498-0.0677.hdf5
#
# Epoch 00499: val_loss did not improve from 0.06773
#
# Epoch 00500: val_loss did not improve from 0.06773
#
# Epoch 00501: val_loss did not improve from 0.06773
#
# Epoch 00502: val_loss did not improve from 0.06773
#
# Epoch 00503: val_loss did not improve from 0.06773
#
# Epoch 00504: val_loss did not improve from 0.06773
#
# Epoch 00505: val_loss did not improve from 0.06773
#
# Epoch 00506: val_loss improved from 0.06773 to 0.06714, saving model to ./model/506-0.0671.hdf5
#
# Epoch 00507: val_loss did not improve from 0.06714
#
# Epoch 00508: val_loss did not improve from 0.06714
#
# Epoch 00509: val_loss did not improve from 0.06714
#
# Epoch 00510: val_loss did not improve from 0.06714
#
# Epoch 00511: val_loss did not improve from 0.06714
#
# Epoch 00512: val_loss did not improve from 0.06714
#
# Epoch 00513: val_loss improved from 0.06714 to 0.06686, saving model to ./model/513-0.0669.hdf5
#
# Epoch 00514: val_loss did not improve from 0.06686
#
# Epoch 00515: val_loss did not improve from 0.06686
#
# Epoch 00516: val_loss improved from 0.06686 to 0.06622, saving model to ./model/516-0.0662.hdf5
#
# Epoch 00517: val_loss did not improve from 0.06622
#
# Epoch 00518: val_loss did not improve from 0.06622
#
# Epoch 00519: val_loss did not improve from 0.06622
#
# Epoch 00520: val_loss did not improve from 0.06622
#
# Epoch 00521: val_loss did not improve from 0.06622
#
# Epoch 00522: val_loss did not improve from 0.06622
#
# Epoch 00523: val_loss improved from 0.06622 to 0.06357, saving model to ./model/523-0.0636.hdf5
#
# Epoch 00524: val_loss did not improve from 0.06357
#
# Epoch 00525: val_loss did not improve from 0.06357
#
# Epoch 00526: val_loss did not improve from 0.06357
#
# Epoch 00527: val_loss improved from 0.06357 to 0.06271, saving model to ./model/527-0.0627.hdf5
# Epoch 00528: val_loss did not improve from 0.06271
#
# Epoch 00529: val_loss did not improve from 0.06271
#
# Epoch 00530: val_loss improved from 0.06271 to 0.06264, saving model to ./model/530-0.0626.hdf5
#
# Epoch 00531: val_loss did not improve from 0.06264
#
# Epoch 00532: val_loss did not improve from 0.06264
#
# Epoch 00533: val_loss did not improve from 0.06264
#
# Epoch 00534: val_loss did not improve from 0.06264
#
# Epoch 00535: val_loss did not improve from 0.06264
#
# Epoch 00536: val_loss did not improve from 0.06264
#
# Epoch 00537: val_loss did not improve from 0.06264
#
# Epoch 00538: val_loss did not improve from 0.06264
#
# Epoch 00539: val_loss did not improve from 0.06264
#
# Epoch 00540: val_loss did not improve from 0.06264
#
# Epoch 00541: val_loss did not improve from 0.06264
#
# Epoch 00542: val_loss did not improve from 0.06264
#
# Epoch 00543: val_loss improved from 0.06264 to 0.06211, saving model to ./model/543-0.0621.hdf5
#
# Epoch 00544: val_loss did not improve from 0.06211
#
# Epoch 00545: val_loss did not improve from 0.06211
#
# Epoch 00546: val_loss did not improve from 0.06211
#
# Epoch 00547: val_loss improved from 0.06211 to 0.06139, saving model to ./model/547-0.0614.hdf5
#
# Epoch 00548: val_loss did not improve from 0.06139
#
# Epoch 00549: val_loss did not improve from 0.06139
#
# Epoch 00550: val_loss did not improve from 0.06139
#
# Epoch 00551: val_loss did not improve from 0.06139
#
# Epoch 00552: val_loss did not improve from 0.06139
#
# Epoch 00553: val_loss did not improve from 0.06139
#
# Epoch 00554: val_loss improved from 0.06139 to 0.06112, saving model to ./model/554-0.0611.hdf5
#
# Epoch 00555: val_loss did not improve from 0.06112
#
# Epoch 00556: val_loss did not improve from 0.06112
#
# Epoch 00557: val_loss did not improve from 0.06112
#
# Epoch 00558: val_loss did not improve from 0.06112
#
# Epoch 00559: val_loss did not improve from 0.06112
#
# Epoch 00560: val_loss improved from 0.06112 to 0.06100, saving model to ./model/560-0.0610.hdf5
#
# Epoch 00561: val_loss did not improve from 0.06100
#
# Epoch 00562: val_loss did not improve from 0.06100
#
# Epoch 00563: val_loss did not improve from 0.06100
#
# Epoch 00564: val_loss did not improve from 0.06100
#
# Epoch 00565: val_loss improved from 0.06100 to 0.06097, saving model to ./model/565-0.0610.hdf5
#
# Epoch 00566: val_loss improved from 0.06097 to 0.06018, saving model to ./model/566-0.0602.hdf5
#
# Epoch 00567: val_loss did not improve from 0.06018
#
# Epoch 00568: val_loss did not improve from 0.06018
#
# Epoch 00569: val_loss did not improve from 0.06018
#
# Epoch 00570: val_loss did not improve from 0.06018
#
# Epoch 00571: val_loss did not improve from 0.06018
#
# Epoch 00572: val_loss did not improve from 0.06018
#
# Epoch 00573: val_loss did not improve from 0.06018
#
# Epoch 00574: val_loss improved from 0.06018 to 0.05913, saving model to ./model/574-0.0591.hdf5
#
# Epoch 00575: val_loss did not improve from 0.05913
#
# Epoch 00576: val_loss did not improve from 0.05913
#
# Epoch 00577: val_loss improved from 0.05913 to 0.05892, saving model to ./model/577-0.0589.hdf5
#
# Epoch 00578: val_loss improved from 0.05892 to 0.05872, saving model to ./model/578-0.0587.hdf5
#
# Epoch 00579: val_loss did not improve from 0.05872
#
# Epoch 00580: val_loss improved from 0.05872 to 0.05737, saving model to ./model/580-0.0574.hdf5
#
# Epoch 00581: val_loss did not improve from 0.05737
#
# Epoch 00582: val_loss did not improve from 0.05737
#
# Epoch 00583: val_loss did not improve from 0.05737
#
# Epoch 00584: val_loss did not improve from 0.05737
#
# Epoch 00585: val_loss did not improve from 0.05737
#
# Epoch 00586: val_loss did not improve from 0.05737
#
# Epoch 00587: val_loss did not improve from 0.05737
#
# Epoch 00588: val_loss did not improve from 0.05737
#
# Epoch 00589: val_loss did not improve from 0.05737
#
# Epoch 00590: val_loss did not improve from 0.05737
#
# Epoch 00591: val_loss did not improve from 0.05737
#
# Epoch 00592: val_loss did not improve from 0.05737
#
# Epoch 00593: val_loss did not improve from 0.05737
#
# Epoch 00594: val_loss did not improve from 0.05737
#
# Epoch 00595: val_loss did not improve from 0.05737
#
# Epoch 00596: val_loss did not improve from 0.05737
#
# Epoch 00597: val_loss did not improve from 0.05737
#
# Epoch 00598: val_loss improved from 0.05737 to 0.05603, saving model to ./model/598-0.0560.hdf5
#
# Epoch 00599: val_loss did not improve from 0.05603
#
# Epoch 00600: val_loss did not improve from 0.05603
#
# Epoch 00601: val_loss did not improve from 0.05603
#
# Epoch 00602: val_loss did not improve from 0.05603
#
# Epoch 00603: val_loss did not improve from 0.05603
#
# Epoch 00604: val_loss did not improve from 0.05603
#
# Epoch 00605: val_loss did not improve from 0.05603
#
# Epoch 00606: val_loss did not improve from 0.05603
#
# Epoch 00607: val_loss did not improve from 0.05603
#
# Epoch 00608: val_loss did not improve from 0.05603
#
# Epoch 00609: val_loss did not improve from 0.05603
#
# Epoch 00610: val_loss did not improve from 0.05603
#
# Epoch 00611: val_loss improved from 0.05603 to 0.05544, saving model to ./model/611-0.0554.hdf5
#
# Epoch 00612: val_loss did not improve from 0.05544
#
# Epoch 00613: val_loss did not improve from 0.05544
#
# Epoch 00614: val_loss improved from 0.05544 to 0.05534, saving model to ./model/614-0.0553.hdf5
#
# Epoch 00615: val_loss did not improve from 0.05534
#
# Epoch 00616: val_loss did not improve from 0.05534
#
# Epoch 00617: val_loss did not improve from 0.05534
#
# Epoch 00618: val_loss improved from 0.05534 to 0.05507, saving model to ./model/618-0.0551.hdf5
#
# Epoch 00619: val_loss did not improve from 0.05507
#
# Epoch 00620: val_loss did not improve from 0.05507
#
# Epoch 00621: val_loss improved from 0.05507 to 0.05445, saving model to ./model/621-0.0545.hdf5
#
# Epoch 00622: val_loss did not improve from 0.05445
#
# Epoch 00623: val_loss did not improve from 0.05445
#
# Epoch 00624: val_loss did not improve from 0.05445
#
# Epoch 00625: val_loss improved from 0.05445 to 0.05329, saving model to ./model/625-0.0533.hdf5
#
# Epoch 00626: val_loss did not improve from 0.05329
#
# Epoch 00627: val_loss did not improve from 0.05329
#
# Epoch 00628: val_loss improved from 0.05329 to 0.05313, saving model to ./model/628-0.0531.hdf5
#
# Epoch 00629: val_loss did not improve from 0.05313
#
# Epoch 00630: val_loss did not improve from 0.05313
#
# Epoch 00631: val_loss did not improve from 0.05313
#
# Epoch 00632: val_loss did not improve from 0.05313
#
# Epoch 00633: val_loss did not improve from 0.05313
#
# Epoch 00634: val_loss did not improve from 0.05313
#
# Epoch 00635: val_loss did not improve from 0.05313
#
# Epoch 00636: val_loss did not improve from 0.05313
#
# Epoch 00637: val_loss did not improve from 0.05313
#
# Epoch 00638: val_loss did not improve from 0.05313
#
# Epoch 00639: val_loss did not improve from 0.05313
#
# Epoch 00640: val_loss did not improve from 0.05313
#
# Epoch 00641: val_loss did not improve from 0.05313
#
# Epoch 00642: val_loss did not improve from 0.05313
#
# Epoch 00643: val_loss did not improve from 0.05313
#
# Epoch 00644: val_loss did not improve from 0.05313
#
# Epoch 00645: val_loss improved from 0.05313 to 0.05256, saving model to ./model/645-0.0526.hdf5
#
# Epoch 00646: val_loss did not improve from 0.05256
#
# Epoch 00647: val_loss did not improve from 0.05256
#
# Epoch 00648: val_loss improved from 0.05256 to 0.05203, saving model to ./model/648-0.0520.hdf5
#
# Epoch 00649: val_loss did not improve from 0.05203
#
# Epoch 00650: val_loss did not improve from 0.05203
#
# Epoch 00651: val_loss did not improve from 0.05203
#
# Epoch 00652: val_loss did not improve from 0.05203
#
# Epoch 00653: val_loss did not improve from 0.05203
#
# Epoch 00654: val_loss did not improve from 0.05203
#
# Epoch 00655: val_loss did not improve from 0.05203
#
# Epoch 00656: val_loss did not improve from 0.05203
#
# Epoch 00657: val_loss did not improve from 0.05203
#
# Epoch 00658: val_loss did not improve from 0.05203
#
# Epoch 00659: val_loss did not improve from 0.05203
#
# Epoch 00660: val_loss did not improve from 0.05203
#
# Epoch 00661: val_loss did not improve from 0.05203
#
# Epoch 00662: val_loss improved from 0.05203 to 0.05150, saving model to ./model/662-0.0515.hdf5
#
# Epoch 00663: val_loss did not improve from 0.05150
#
# Epoch 00664: val_loss did not improve from 0.05150
#
# Epoch 00665: val_loss improved from 0.05150 to 0.05135, saving model to ./model/665-0.0514.hdf5
#
# Epoch 00666: val_loss did not improve from 0.05135
#
# Epoch 00667: val_loss did not improve from 0.05135
#
# Epoch 00668: val_loss did not improve from 0.05135
#
# Epoch 00669: val_loss improved from 0.05135 to 0.05033, saving model to ./model/669-0.0503.hdf5
# Epoch 00670: val_loss did not improve from 0.05033
#
# Epoch 00671: val_loss improved from 0.05033 to 0.04992, saving model to ./model/671-0.0499.hdf5
#
# Epoch 00672: val_loss did not improve from 0.04992
#
# Epoch 00673: val_loss did not improve from 0.04992
#
# Epoch 00674: val_loss did not improve from 0.04992
#
# Epoch 00675: val_loss did not improve from 0.04992
#
# Epoch 00676: val_loss did not improve from 0.04992
#
# Epoch 00677: val_loss improved from 0.04992 to 0.04882, saving model to ./model/677-0.0488.hdf5
#
# Epoch 00678: val_loss did not improve from 0.04882
#
# Epoch 00679: val_loss did not improve from 0.04882
#
# Epoch 00680: val_loss improved from 0.04882 to 0.04843, saving model to ./model/680-0.0484.hdf5
#
# Epoch 00681: val_loss did not improve from 0.04843
#
# Epoch 00682: val_loss did not improve from 0.04843
#
# Epoch 00683: val_loss did not improve from 0.04843
#
# Epoch 00684: val_loss did not improve from 0.04843
#
# Epoch 00685: val_loss did not improve from 0.04843
#
# Epoch 00686: val_loss did not improve from 0.04843
#
# Epoch 00687: val_loss did not improve from 0.04843
#
# Epoch 00688: val_loss did not improve from 0.04843
#
# Epoch 00689: val_loss did not improve from 0.04843
#
# Epoch 00690: val_loss did not improve from 0.04843
#
# Epoch 00691: val_loss did not improve from 0.04843
#
# Epoch 00692: val_loss did not improve from 0.04843
#
# Epoch 00693: val_loss did not improve from 0.04843
#
# Epoch 00694: val_loss improved from 0.04843 to 0.04837, saving model to ./model/694-0.0484.hdf5
#
# Epoch 00695: val_loss did not improve from 0.04837
#
# Epoch 00696: val_loss did not improve from 0.04837
#
# Epoch 00697: val_loss did not improve from 0.04837
#
# Epoch 00698: val_loss improved from 0.04837 to 0.04643, saving model to ./model/698-0.0464.hdf5
#
# Epoch 00699: val_loss improved from 0.04643 to 0.04608, saving model to ./model/699-0.0461.hdf5
#
# Epoch 00700: val_loss did not improve from 0.04608
#
# Epoch 00701: val_loss improved from 0.04608 to 0.04514, saving model to ./model/701-0.0451.hdf5
#
# Epoch 00702: val_loss improved from 0.04514 to 0.04397, saving model to ./model/702-0.0440.hdf5
#
# Epoch 00703: val_loss did not improve from 0.04397
#
# Epoch 00704: val_loss did not improve from 0.04397
#
# Epoch 00705: val_loss improved from 0.04397 to 0.04233, saving model to ./model/705-0.0423.hdf5
#
# Epoch 00706: val_loss improved from 0.04233 to 0.04153, saving model to ./model/706-0.0415.hdf5
#
# Epoch 00707: val_loss did not improve from 0.04153
#
# Epoch 00708: val_loss did not improve from 0.04153
#
# Epoch 00709: val_loss did not improve from 0.04153
#
# Epoch 00710: val_loss did not improve from 0.04153
#
# Epoch 00711: val_loss did not improve from 0.04153
#
# Epoch 00712: val_loss did not improve from 0.04153
#
# Epoch 00713: val_loss did not improve from 0.04153
#
# Epoch 00714: val_loss did not improve from 0.04153
#
# Epoch 00715: val_loss did not improve from 0.04153
#
# Epoch 00716: val_loss did not improve from 0.04153
#
# Epoch 00717: val_loss did not improve from 0.04153
#
# Epoch 00718: val_loss did not improve from 0.04153
#
# Epoch 00719: val_loss did not improve from 0.04153
#
# Epoch 00720: val_loss did not improve from 0.04153
#
# Epoch 00721: val_loss did not improve from 0.04153
#
# Epoch 00722: val_loss did not improve from 0.04153
#
# Epoch 00723: val_loss did not improve from 0.04153
#
# Epoch 00724: val_loss did not improve from 0.04153
#
# Epoch 00725: val_loss did not improve from 0.04153
#
# Epoch 00726: val_loss did not improve from 0.04153
#
# Epoch 00727: val_loss did not improve from 0.04153
#
# Epoch 00728: val_loss did not improve from 0.04153
#
# Epoch 00729: val_loss did not improve from 0.04153
#
# Epoch 00730: val_loss did not improve from 0.04153
#
# Epoch 00731: val_loss did not improve from 0.04153
#
# Epoch 00732: val_loss did not improve from 0.04153
#
# Epoch 00733: val_loss did not improve from 0.04153
#
# Epoch 00734: val_loss did not improve from 0.04153
#
# Epoch 00735: val_loss did not improve from 0.04153
#
# Epoch 00736: val_loss did not improve from 0.04153
#
# Epoch 00737: val_loss did not improve from 0.04153
#
# Epoch 00738: val_loss did not improve from 0.04153
#
# Epoch 00739: val_loss did not improve from 0.04153
#
# Epoch 00740: val_loss did not improve from 0.04153
#
# Epoch 00741: val_loss did not improve from 0.04153
#
# Epoch 00742: val_loss did not improve from 0.04153
#
# Epoch 00743: val_loss did not improve from 0.04153
#
# Epoch 00744: val_loss did not improve from 0.04153
#
# Epoch 00745: val_loss did not improve from 0.04153
#
# Epoch 00746: val_loss did not improve from 0.04153
#
# Epoch 00747: val_loss did not improve from 0.04153
#
# Epoch 00748: val_loss did not improve from 0.04153
#
# Epoch 00749: val_loss did not improve from 0.04153
#
# Epoch 00750: val_loss did not improve from 0.04153
#
# Epoch 00751: val_loss did not improve from 0.04153
#
# Epoch 00752: val_loss did not improve from 0.04153
#
# Epoch 00753: val_loss did not improve from 0.04153
#
# Epoch 00754: val_loss did not improve from 0.04153
#
# Epoch 00755: val_loss did not improve from 0.04153
#
# Epoch 00756: val_loss did not improve from 0.04153
#
# Epoch 00757: val_loss did not improve from 0.04153
#
# Epoch 00758: val_loss did not improve from 0.04153
#
# Epoch 00759: val_loss did not improve from 0.04153
#
# Epoch 00760: val_loss did not improve from 0.04153
#
# Epoch 00761: val_loss did not improve from 0.04153
#
# Epoch 00762: val_loss did not improve from 0.04153
#
# Epoch 00763: val_loss did not improve from 0.04153
#
# Epoch 00764: val_loss did not improve from 0.04153
#
# Epoch 00765: val_loss did not improve from 0.04153
#
# Epoch 00766: val_loss did not improve from 0.04153
#
# Epoch 00767: val_loss did not improve from 0.04153
#
# Epoch 00768: val_loss did not improve from 0.04153
#
# Epoch 00769: val_loss did not improve from 0.04153
#
# Epoch 00770: val_loss did not improve from 0.04153
#
# Epoch 00771: val_loss did not improve from 0.04153
#
# Epoch 00772: val_loss did not improve from 0.04153
#
# Epoch 00773: val_loss did not improve from 0.04153
#
# Epoch 00774: val_loss did not improve from 0.04153
#
# Epoch 00775: val_loss did not improve from 0.04153
#
# Epoch 00776: val_loss did not improve from 0.04153
#
# Epoch 00777: val_loss did not improve from 0.04153
#
# Epoch 00778: val_loss did not improve from 0.04153
#
# Epoch 00779: val_loss did not improve from 0.04153
#
# Epoch 00780: val_loss did not improve from 0.04153
#
# Epoch 00781: val_loss did not improve from 0.04153
#
# Epoch 00782: val_loss did not improve from 0.04153
#
# Epoch 00783: val_loss did not improve from 0.04153
#
# Epoch 00784: val_loss did not improve from 0.04153
#
# Epoch 00785: val_loss did not improve from 0.04153
#
# Epoch 00786: val_loss did not improve from 0.04153
#
# Epoch 00787: val_loss did not improve from 0.04153
#
# Epoch 00788: val_loss did not improve from 0.04153
#
# Epoch 00789: val_loss did not improve from 0.04153
#
# Epoch 00790: val_loss did not improve from 0.04153
#
# Epoch 00791: val_loss did not improve from 0.04153
#
# Epoch 00792: val_loss did not improve from 0.04153
#
# Epoch 00793: val_loss did not improve from 0.04153
#
# Epoch 00794: val_loss did not improve from 0.04153
#
# Epoch 00795: val_loss did not improve from 0.04153
#
# Epoch 00796: val_loss did not improve from 0.04153
#
# Epoch 00797: val_loss did not improve from 0.04153
#
# Epoch 00798: val_loss did not improve from 0.04153
#
# Epoch 00799: val_loss did not improve from 0.04153
#
# Epoch 00800: val_loss did not improve from 0.04153
#
# Epoch 00801: val_loss did not improve from 0.04153
#
# Epoch 00802: val_loss did not improve from 0.04153
#
# Epoch 00803: val_loss did not improve from 0.04153
#
# Epoch 00804: val_loss did not improve from 0.04153
#
# Epoch 00805: val_loss did not improve from 0.04153
#
# Epoch 00806: val_loss did not improve from 0.04153
# 975/975 [==============================] - 0s 25us/step
#
#  Accuracy: 0.9938
